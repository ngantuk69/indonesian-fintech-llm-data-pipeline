# %% [markdown]
# # Data Cleaning Pipeline
#
# Notebook ini mendokumentasikan proses *data cleaning* untuk dataset pesan pelanggan fintech Indonesia.
#
# Tahapan utama:
# 1. Load konfigurasi dan data mentah
# 2. Cleaning otomatis (deduplikasi, normalisasi, filter panjang & bahasa)
# 3. Validasi hasil cleaning
# 4. Penyimpanan output terstruktur
# 5. Visualisasi statistik cleaning
#
# Notebook ini berfungsi sebagai **audit trail** dan **reproducible experiment** untuk tahap preprocessing sebelum labeling.

# %% [markdown]
# ## 1. Import Library & Module
# Mengimpor library yang digunakan serta fungsi cleaning & validation dari folder `scripts/`.

# %%
import sys
from pathlib import Path

# Tambahkan parent folder dari notebooks ke sys.path
sys.path.append(str(Path().resolve().parent))

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\ACER NITRO 5\OneDrive\Desktop\koding\indonesian-fintech-llm-data-pipeline\notebooks

# %%
import pandas as pd
import yaml
import json
from pathlib import Path
import matplotlib.pyplot as plt

from scripts.preprocess import clean_pipeline
from scripts.validate import validate_dataframe
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 7
#       4 from pathlib import Path
#       5 import matplotlib.pyplot as plt
# ----> 7 from scripts.preprocess import clean_pipeline
#       8 from scripts.validate import validate_dataframe
#
# ModuleNotFoundError: No module named 'scripts'
